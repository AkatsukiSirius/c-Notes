# %% [markdown]
# # [Enterprise Resource Planning](https://en.wikipedia.org/wiki/Enterprise_resource_planning)

# %% [markdown]
# - ## [For manufacturing or service delivery](https://www.sap.com/products/supply-chain-iot/manufacturing.html)

# %% [markdown]
# # 1. SAP Manufacturing Execution

# %% [markdown]
# ### - Run efficient, high-quality production on the shop floor by integrating business and manufacturing processes with the SAP Manufacturing Execution application.
#
# ### - Access real-time information, improve reliability, and take advantage of global product traceability.

# %% [markdown]
# - ### Hybrid deployment
#
# - ### Integrated production and inspection
#
# - ### Streamlined compliance processes
#
# - ### Paperless manufacturing

# %% [markdown]
# ## 1.1 Manufacturing Execution System (MES)

# %% [markdown]
# - ### Connect, monitor, and tightly control your manufacturing operations – with SAP Manufacturing Execution.
#
# - ### This MES system integrates your business and manufacturing processes to help you run efficient, high quality production on the shop floor.
#
# - ### Access real-time information, improve reliability, and take advantage of global product traceability.

# %% [markdown]
# - ### MES, Work station, and Product are connected together;
#
# - ### MES makes these component communicate with each others;
#
# - ### Combine both manual and fully automation control;
#
# - ### Working Flow example:
#
#     - 1) 1st Working station asks for instruction(order information) from MES and
#
#     - 2) Work path can identify it in each step during manufacturing;
#
#     - 3) If mistakes are found, go back to rework station;
#
#     - 4) Indicate it is fixed or not;
#
#     - 5) Analyze the KPI;
#
# ### SAP Connected Manufactoring

# %% [markdown]
# ### Open Integrated Factory
#
# ### Open Technology Standards

# %%
from PIL import Image

# %%
Image.open('SPA1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=738x368 at 0x1070BF438>

# %%
Image.open('SPA3.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=414x710 at 0x1070A1F60>

# %% [markdown]
# ### 1) Asking for work, order information; and release for execution;generate a SCF code. Record it to RFID,a chip;
#
# ### 2) Read SCF;
#
# ### 3）Read SCF, ask ME for parameters;

# %% [markdown]
# ...

# %% [markdown]
# |Manufacturing Execution System (MES)||
# |:-|:-|
# |Platform|SAP Manufacturing Execution on Netweaver Java 7.5|
# |Operating Systems|Windows Server, LINUX, UNIX, AIX|
# |Databases|SAP HANA, MS SQL Server and Oracle DBMS|
# |Supplemental Components|Co-located MII 15.1 with MEINT ECC integration content, and PCo 15.1 for shop floor integration|
# |Languages|Multiple languages available|

# %% [markdown]
# ## 1.2 [Business intelligence (BI) solutions](https://www.sap.com/products/analytics/business-intelligence-bi.html)

# %% [markdown]
# - ## [SAP Analytics Hub](https://www.sap.com/products/analytics-hub.html)
#
# - ## [SAP Analytics Cloud](https://www.sap.com/products/cloud-analytics/features/business-intelligence.html)

# %% [markdown]
# # 2. [SAP Manufacturing Intelligence Integration](https://www.sap.com/products/manufacturing-intelligence-integration.html)

# %% [markdown]
# ### Become a highly adaptive manufacturer with SAP Manufacturing Integration and Intelligence (SAP MII).
#
# ### The software can help you leverage the Industrial Internet of Things (IIoT) by connecting your equipment, people, and operations to your extended supply chain.
#
# ### Get the manufacturing intelligence and visibility you need to run in real time – and tightly integrate your manufacturing processes with business operations.

# %% [markdown]
# - ## Plant information catalog
#
#     - ### Arrange shop floor assets in a hierarchical structure. Maintain master data and let sensors and business users add additional information.
#
# - ## Manufacturing analytics platform
#
#     - ### Take advantage of an in-memory platform that supports cross-data-store analysis, statistical process control, predictive analytics, and storage for Big Data.
#
# - ## Overall equipment effectiveness (OEE)
#
#     - ### Identify the root causes of equipment downtime, efficiency loss, and poor quality on various hierarchy levels – and view them in business context.
#
# - ## Energy monitoring and analysis
#
#     - ### Simplify all aspects of energy monitoring and analysis across different dimensions of the plant information catalog – from buildings to manufacturing networks.
#
# - ## User-definable dashboards
#
#     - ### Consume role-based production data on your desktop or mobile device. Use drag-and-drop tools to define personal views according to plant hierarchy.
#
# - ## Business process integration
#
#     - ### Tie intelligent business processes from the enterprise to production – and even to device connections.
#
# - ## Event management
#
#     - ### Get instant insight – and take quick action – with real-time event detection, processing, and management.
